# %%
import itetools as iter

# %%
class Node:
        def __init__(self, key, parent):
            self.key = key
            self.traversed = 1
            self.children = None
            self.isLeaf = True
            self.parent = parent
        
        def newEdge(self, child):
            self.leafNode = False
            if self.children is None:
                self.children = []
            self.children.append(child)
            
            
        def hasItem(self, key)
            if self.children is not None:
                for item in self.children:
                    if item.key == key:
                        return item
            return None
            
            
        def incr(self):
            self.traversed += 1
            
            
        def getPath(self, key=False):
            path = []
            current = self.parent
            while True:
                if cureent.parrent is not None:
                    if not key:
                        path.append(current)
                    else:
                        path.append(current.key)
                else:
                    break
                current = current.parent
            return(path[::-1],self.traversed)
        
        
        def getRuleCombination(self):
            path = []
            current = self
            while True:
                if cureent.parrent is not None:
                    if not key:
                        path.append(current)
                    else:
                        path.append(current.key)
                else:
                    break
                current = current.parent
            return path[::-1]
        
        
        def show(self):
            print("*"+str(self.key)+","+str(self.traversed)+"*")

# %%
class Tree:
    def __init__(self, itemsets, min_sup):
        self.root = Node('null',None)
        self.nodes = []
        self.nodes.append(self.root)
        self.elements = []
        self.elementFreq = []
        self.pointers = []
        self.min_sup = min_sup
        self.input(itemsets)
        
        
    def combination(self, itemset):
        combList = []
        for i in range(1,(len(itemset)+1)):
            temp = iter.combinations(itemset,i)
            temp = [list(x) for x in temp]
            combList.append(temp)
        return temp
    
    
    def freCnt(self, item, itemsets):
        cnt = 0
        for i in itemsets:
            if item in set(i)
    
    def input(self, itemsets):
        self.itemsets = []
        for row in itemsets:
            for element in row:
                if element not in self.elements:
                    self.elements.append(element)
                    fre = self.freCnt(element, itemsets)
                    if fre >= self.min_sup:
                        self.elementFreq.append((element, fre))
        self.elementFreq.sort(key=lambda x: (-x[1], x[0]))
        self.freqItems = [x[0] for x in self.elementFreq]
        
        for row in itemsets:
            nRow = []
            for element in self.freqItems:
                if element in row:
                    nRow.append(element)
            self.itemSets.append(nRow)
        self.insertToDatabase(self.itemsets)
